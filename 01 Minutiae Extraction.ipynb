# %%
import os
import cv2

from matplotlib import pyplot as plt

# %%
sample = cv2.imread("dataset/SCOCOFing/Real/1__M_Left_index_finger.BMP")
sample = cv2.resize(sample, None, fx=2.5, fy=2.5)

plt.imshow(sample)
plt.title("FP image")
plt.show()
